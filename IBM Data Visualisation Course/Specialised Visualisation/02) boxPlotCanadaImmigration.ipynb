# %%
# %matplotlib notebook
#Import Needed Modules
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#Read the file
df_canada = pd.read_excel('Canada.xlsx',
                         sheet_name="Canada by Citizenship",
                         skiprows=range(20),
                         skipfooter=2)

# %%
# Get summary of dataframe
df_canada.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_canada["Total"] = df_canada[range(1980,2014)].sum(axis=1)

# %%
df_canada_2 = df_canada.set_index('OdName')

# %%
df_canada_2.head()
# Out:
#                       Type    Coverage  AREA AreaName   REG          RegName  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501    Southern Asia
# Albania         Immigrants  Foreigners   908   Europe   925  Southern Europe
# Algeria         Immigrants  Foreigners   903   Africa   912  Northern Africa
# American Samoa  Immigrants  Foreigners   909  Oceania   957        Polynesia
# Andorra         Immigrants  Foreigners   908   Europe   925  Southern Europe
#
#                 DEV             DevName  1980  1981  ...  2005  2006  2007  \
# OdName                                               ...
# Afghanistan     902  Developing regions    16    39  ...  3436  3009  2652
# Albania         901   Developed regions     1     0  ...  1223   856   702
# Algeria         902  Developing regions    80    67  ...  3626  4807  3623
# American Samoa  902  Developing regions     0     1  ...     0     1     0
# ...

# %%
#Filter by countries
#df_canada.OdName

# %%
years = list(map(str, range(1980, 2014)))

# %%
df_canada_2.columns = list(map(str, df_canada_2.columns)) # to prevent ambiguity between index numbers and column names

# %%
df_canada_2.sort_values(['Total'], ascending=False, axis=0, inplace=True)

# %%
df_canada_2
# Out:
#                                                           Type    Coverage  \
# OdName
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
# United States of America                            Immigrants  Foreigners
# Iran (Islamic Republic of)                          Immigrants  Foreigners
# Sri Lanka                                           Immigrants  Foreigners
# Republic of Korea                                   Immigrants  Foreigners
# Poland                                              Immigrants  Foreigners
# Lebanon                                             Immigrants  Foreigners
# ...

# %%
# Get Japan data as a dataframe
df_japan = df_canada_2.loc[['Japan'], years].transpose()
df_japan.head()
# Out:
# OdName  Japan
# 1980      701
# 1981      756
# 1982      598
# 1983      309
# 1984      246

# %%
df_japan.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of Japanese Immigrants from 1980 - 2013')
plt.ylabel('Number of Immigrants')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Get Summary data Statistics

df_japan.describe()
# Out:
# OdName        Japan
# count     34.000000
# mean     814.911765
# std      337.219771
# min      198.000000
# 25%      529.000000
# 50%      902.000000
# 75%     1079.000000
# max     1284.000000

# %%
df_china_india= df_canada_2.loc[['China', 'India'], years].transpose()
df_china_india.head()
# Out:
# OdName  China  India
# 1980     5123   8880
# 1981     6682   8670
# 1982     3308   8147
# 1983     1863   7338
# 1984     1527   5704

# %%
#Compare Statsistics
df_china_india.describe()
# Out:
# OdName         China         India
# count      34.000000     34.000000
# mean    19410.647059  20350.117647
# std     13568.230790  10007.342579
# min      1527.000000   4211.000000
# 25%      5512.750000  10637.750000
# 50%     19945.000000  20235.000000
# 75%     31568.500000  28699.500000
# max     42584.000000  36210.000000

# %%
# Plots for China and India
df_china_india.plot(kind='box')

plt.title('Box plots of Immigrants from China and India (1980 - 2013)')
plt.xlabel('Number of Immigrants')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Show Plots of two different graphs together
fig = plt.figure() 

ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2) # add subplot 2 (1 row, 2 columns, second plot)

# Subplot 1: Box plot
df_china_india.plot(kind='box', vert=False, ax=ax0) # add to subplot 1
ax0.set_title('Box Plots of Immigrants from China and India (1980 - 2013)')
ax0.set_xlabel('Number of Immigrants')
ax0.set_ylabel('Countries')

# Subplot 2: Line plot
df_china_india.plot(kind='line', ax=ax1) # add to subplot 2
ax1.set_title ('Line Plots of Immigrants from China and India (1980 - 2013)')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1328">
